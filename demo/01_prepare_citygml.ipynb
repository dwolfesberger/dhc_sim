# %% [markdown]
# ## 1. Download CityGML files form OGD Vienna
#
# https://www.wien.gv.at/ma41datenviewer/public/start.aspx
#
# Select **Generalisiertes Dachmodell (LOD2.1)** and download areas of interest to get CityGML files.

# %% [markdown]
# ## 2. Process CityGML-files
#
# Edit GML files with GMLProcesser class:
# - gml files from OGD Vienna are missing address information
# - calculate centroid of building footprint
# - convert centroid coordinates to WRG84 (OSM) to get correct address information
# - get address information from OSM
# - extend building elements in GML with xAL address elements
# - change building name to address for better identification

# %%
import os
import sys
from pathlib import Path
sys.path.append(str(Path().absolute().parent))

from dhc_sim.processing.citygml import GMLProcessor
from dhc_sim.utils import find_files_by_extension

current_dir = os.getcwd()

path = os.path.join(current_dir, 'data', 'citygml_files', 'raw_ogd_vienna')
files = find_files_by_extension(path, 'gml')

output_folder = os.path.join(current_dir, 'data', 'citygml_files', 'preprocessed_citygml')

for file in files:
    file_name = file['file_name']
    input_path = file['path']
    output_path = os.path.join(output_folder, file_name)
    
    print(f"Initializing GML Address Processor for {file_name}")
    processor = GMLProcessor(input_path)
    
    # Process all buildings
    successful_buildings, failed_buildings = processor.process_all_buildings()
    
    # Save the modified file
    processor.save(output_path)
    
    # Print processing statistics
    print("\nProcessing completed!")
    print(f"Successfully processed: {successful_buildings}")
    print(f"Failed to process: {failed_buildings}")
    print(f"Output file saved as: {output_path}")
# Out:
# Initializing GML Address Processor for 100087.gml
# Found 132 buildings
# Creating GeoDataFrame and calculating building footprints...
# Created GeoDataFrame with 132 rows
# Processing building 1/132
# Processing building 2/132
# Processing building 3/132
# Processing building 4/132
# Processing building 5/132
# Processing building 6/132
# Processing building 7/132
# Processing building 8/132
# Processing building 9/132
# Processing building 10/132
# Processing building 11/132
# Processing building 12/132
# Processing building 13/132
# Processing building 14/132
# Processing building 15/132
# Processing building 16/132
# Processing building 17/132
# Processing building 18/132
# Processing building 19/132
# Processing building 20/132
# Processing building 21/132
# Processing building 22/132
# Processing building 23/132
# Processing building 24/132
# Processing building 25/132
# Processing building 26/132
# Processing building 27/132
# Processing building 28/132
# Processing building 29/132
# Processing building 30/132
# Processing building 31/132
# Processing building 32/132
# Processing building 33/132
# Processing building 34/132
# Processing building 35/132
# Processing building 36/132
# Processing building 37/132
# Processing building 38/132
# Processing building 39/132
# Processing building 40/132
# Processing building 41/132
# Processing building 42/132
# Processing building 43/132
# Processing building 44/132
# Processing building 45/132
# Processing building 46/132
# Processing building 47/132
# Processing building 48/132
# Processing building 49/132
# Processing building 50/132
# Processing building 51/132
# Processing building 52/132
# Processing building 53/132
# Processing building 54/132
# Processing building 55/132
# Processing building 56/132
# Processing building 57/132
# Processing building 58/132
# Processing building 59/132
# Processing building 60/132
# Processing building 61/132
# Processing building 62/132
# Processing building 63/132
# Processing building 64/132
# Processing building 65/132
# Processing building 66/132
# Processing building 67/132
# Processing building 68/132
# Processing building 69/132
# Processing building 70/132
# Processing building 71/132
# Processing building 72/132
# Processing building 73/132
# Processing building 74/132
# Processing building 75/132
# Processing building 76/132
# Processing building 77/132
# Processing building 78/132
# Processing building 79/132
# Processing building 80/132
# Processing building 81/132
# Processing building 82/132
# Processing building 83/132
# Processing building 84/132
# Processing building 85/132
# Processing building 86/132
# Processing building 87/132
# Processing building 88/132
# Processing building 89/132
# Processing building 90/132
# Processing building 91/132
# Processing building 92/132
# Processing building 93/132
# Processing building 94/132
# Processing building 95/132
# Processing building 96/132
# Processing building 97/132
# Processing building 98/132
# Processing building 99/132
# Processing building 100/132
# Processing building 101/132
# Processing building 102/132
# Processing building 103/132
# Processing building 104/132
# Processing building 105/132
# Processing building 106/132
# Processing building 107/132
# Processing building 108/132
# Processing building 109/132
# Processing building 110/132
# Processing building 111/132
# Processing building 112/132
# Processing building 113/132
# Processing building 114/132
# Processing building 115/132
# Processing building 116/132
# Processing building 117/132
# Processing building 118/132
# Processing building 119/132
# Processing building 120/132
# Processing building 121/132
# Processing building 122/132
# Processing building 123/132
# Processing building 124/132
# Processing building 125/132
# Processing building 126/132
# Processing building 127/132
# Processing building 128/132
# Processing building 129/132
# Processing building 130/132
# Processing building 131/132
# Processing building 132/132
#
# New CityGML file saved as 'c:\Users\dawo\e7dw\MAA\simulations\06_demo_new\demo\data\citygml_files\preprocessed_citygml\100087.gml'.
#
# Processing completed!
# Successfully processed: 132
# Failed to process: 0
# Output file saved as: c:\Users\dawo\e7dw\MAA\simulations\06_demo_new\demo\data\citygml_files\preprocessed_citygml\100087.gml
# Initializing GML Address Processor for 101087.gml
# Found 217 buildings
# Creating GeoDataFrame and calculating building footprints...
# Created GeoDataFrame with 217 rows
# Processing building 1/217
# Processing building 2/217
# Processing building 3/217
# Processing building 4/217
# Processing building 5/217
# Processing building 6/217
# Processing building 7/217
# Processing building 8/217
# Processing building 9/217
# Processing building 10/217
# Processing building 11/217
# Processing building 12/217
# Processing building 13/217
# Processing building 14/217
# Processing building 15/217
# Processing building 16/217
# Processing building 17/217
# Processing building 18/217
# Processing building 19/217
# Processing building 20/217
# Processing building 21/217
# Processing building 22/217
# Processing building 23/217
# Processing building 24/217
# Processing building 25/217
# Processing building 26/217
# Processing building 27/217
# Processing building 28/217
# Processing building 29/217
# Processing building 30/217
# Processing building 31/217
# Processing building 32/217
# Processing building 33/217
# Processing building 34/217
# Processing building 35/217
# Processing building 36/217
# Processing building 37/217
# Processing building 38/217
# Processing building 39/217
# Processing building 40/217
# Processing building 41/217
# Processing building 42/217
# Processing building 43/217
# Processing building 44/217
# Processing building 45/217
# Processing building 46/217
# Processing building 47/217
# Processing building 48/217
# Processing building 49/217
# Processing building 50/217
# Processing building 51/217
# Processing building 52/217
# Processing building 53/217
# Processing building 54/217
# Processing building 55/217
# Processing building 56/217
# Processing building 57/217
# Processing building 58/217
# Processing building 59/217
# Processing building 60/217
# Processing building 61/217
# Processing building 62/217
# Processing building 63/217
# Processing building 64/217
# Processing building 65/217
# Processing building 66/217
# Processing building 67/217
# Processing building 68/217
# Processing building 69/217
# Processing building 70/217
# Processing building 71/217
# Processing building 72/217
# Processing building 73/217
# Processing building 74/217
# Processing building 75/217
# Processing building 76/217
# Processing building 77/217
# Processing building 78/217
# Processing building 79/217
# Processing building 80/217
# Processing building 81/217
# Processing building 82/217
# Processing building 83/217
# Processing building 84/217
# Processing building 85/217
# Processing building 86/217
# Processing building 87/217
# Processing building 88/217
# Processing building 89/217
# Processing building 90/217
# Processing building 91/217
# Processing building 92/217
# Processing building 93/217
# Processing building 94/217
# Processing building 95/217
# Processing building 96/217
# Processing building 97/217
# Processing building 98/217
# Processing building 99/217
# Processing building 100/217
# Processing building 101/217
# Processing building 102/217
# Processing building 103/217
# Processing building 104/217
# Processing building 105/217
# Processing building 106/217
# Processing building 107/217
# Processing building 108/217
# Processing building 109/217
# Processing building 110/217
# Processing building 111/217
# Processing building 112/217
# Processing building 113/217
# Processing building 114/217
# Processing building 115/217
# Processing building 116/217
# Processing building 117/217
# Processing building 118/217
# Processing building 119/217
# Processing building 120/217
# Processing building 121/217
# Processing building 122/217
# Processing building 123/217
# Processing building 124/217
# Processing building 125/217
# Processing building 126/217
# Processing building 127/217
# Processing building 128/217
# Processing building 129/217
# Processing building 130/217
# Processing building 131/217
# Processing building 132/217
# Processing building 133/217
# Processing building 134/217
# Processing building 135/217
# Processing building 136/217
# Processing building 137/217
# Processing building 138/217
# Processing building 139/217
# Processing building 140/217
# Processing building 141/217
# Processing building 142/217
# Processing building 143/217
# Processing building 144/217
# Processing building 145/217
# Processing building 146/217
# Processing building 147/217
# Processing building 148/217
# Processing building 149/217
# Processing building 150/217
# Processing building 151/217
# Processing building 152/217
# Processing building 153/217
# Processing building 154/217
# Processing building 155/217
# Processing building 156/217
# Processing building 157/217
# Processing building 158/217
# Processing building 159/217
# Processing building 160/217
# Processing building 161/217
# Processing building 162/217
# Processing building 163/217
# Processing building 164/217
# Processing building 165/217
# Processing building 166/217
# Processing building 167/217
# Processing building 168/217
# Processing building 169/217
# Processing building 170/217
# Processing building 171/217
# Processing building 172/217
# Processing building 173/217
# Processing building 174/217
# Processing building 175/217
# Processing building 176/217
# Processing building 177/217
# Processing building 178/217
# Processing building 179/217
# Processing building 180/217
# Processing building 181/217
# Processing building 182/217
# Processing building 183/217
# Processing building 184/217
# Processing building 185/217
# Processing building 186/217
# Processing building 187/217
# Processing building 188/217
# Processing building 189/217
# Processing building 190/217
# Processing building 191/217
# Processing building 192/217
# Processing building 193/217
# Processing building 194/217
# Processing building 195/217
# Processing building 196/217
# Processing building 197/217
# Processing building 198/217
# Processing building 199/217
# Processing building 200/217
# Processing building 201/217
# Processing building 202/217
# Processing building 203/217
# Processing building 204/217
# Processing building 205/217
# Processing building 206/217
# Processing building 207/217
# Processing building 208/217
# Processing building 209/217
# Processing building 210/217
# Processing building 211/217
# Processing building 212/217
# Processing building 213/217
# Processing building 214/217
# Processing building 215/217
# Processing building 216/217
# Processing building 217/217
#
# New CityGML file saved as 'c:\Users\dawo\e7dw\MAA\simulations\06_demo_new\demo\data\citygml_files\preprocessed_citygml\101087.gml'.
#
# Processing completed!
# Successfully processed: 217
# Failed to process: 0
# Output file saved as: c:\Users\dawo\e7dw\MAA\simulations\06_demo_new\demo\data\citygml_files\preprocessed_citygml\101087.gml

# %% [markdown]
# ## 3. Import GMLs in 3DCityDB
# - open 3D City Database Importer/Exporter
# - connect to DB
# - select preprocessed GMLs an import in DB
#
# **Importer Console output:**
# ```
# [13:10:41 INFO] Initializing database import...
# [13:10:42 INFO] Spatial indexes are enabled.
# [13:10:42 INFO] Normal indexes are enabled.
# [13:10:42 INFO] Creating list of files to be imported...
# [13:10:43 INFO] List of import files successfully created.
# [13:10:43 INFO] 9 file(s) will be imported.
# [13:11:52 INFO] Imported city objects:
# [13:11:52 INFO] bldg:Building: 1507
# [13:11:52 INFO] bldg:BuildingPart: 3931
# [13:11:52 INFO] bldg:GroundSurface: 4463
# [13:11:52 INFO] bldg:RoofSurface: 16735
# [13:11:52 INFO] bldg:WallSurface: 55325
# [13:11:52 INFO] Processed geometry objects: 392833
# [13:11:52 INFO] Total import time: 01 m, 11 s.
# [13:11:52 INFO] Database import successfully finished.
# ```

# %% [markdown]
# ## 4. Connect QGIS to 3DCityDB
#
# ### Establish DB-Connection
# - Install "3DCityDB Tool for QGIS" plugin
# - Open 3DCityDB admin panel
# - Install server-side QGIS Package to the database
# - Add Database user to QGIS Package user group
# - Create DB schema for user-related QGIS data
#
#
# <img src="./pics/01_04_01.png" width="400">
#
# ### Load 3DCityDB Layer
#
# - select db connection
# - connect to db
# - create layers for schema 'citydb' and refresh layers (only needs to be done at first import)
# - select boundary box to import only area of interest

# %% [markdown]
# ## 5. Edit citygml features of buildings in QGIS
#
# **Calculate storeys above ground**
# - citygml from OGD Vienna doesn't countain information about storey heights and storey numbers
# - calculate parameter "storeys_above_ground" with QGIS field calculater
#     - formular:
#
#         ```python
#             if(floor(Height / 3.6) < 1, 1, floor(Height / 3.6))
#         ```
#     - floor function = round down
#     - 3.6 = average height of floor in m
# - calculate parameter "storey_height_above_ground"
#     - formular:
#
#         ```python
#             round("measured_height" / "storeys_above_ground", 2)
#         ```
# - set parameter "storey_height_ag_unit" to m
# - set parameter "storeys_below_ground" to 0
# - set parameter "storey_height_below_ground" to 0
# - set parameter "storey_height_bg_unit" to m
#
# **Set Year of construction and usage**
# - set year of construction for all buildings to 1908 (only for demonstration)
# - set Class = "1000" --> Habitat
# - set Function = "1000" --> Residential Building
# - set Usage = "1000" --> Residential

# %% [markdown]
# ## 6. Export area of interest as citygml file
#
# **Add generict attribute in 3DCityDB**
# - add generic attribute "teaser_export" to flag buildings for teaser export
# - for every cityobject set attr "teaser_export" to false
#
#     ```sql
#     INSERT INTO cityobject_genericattrib (attrname, datatype, strval, cityobject_id)
#     SELECT 'teaser_export', 1, 'false', id
#     FROM cityobject;
#     ```
# **Flag buildings for export in QGIS**
# - select buildings and edit generic building attribute "teaser_export"
# - set attribute to "true"
# - **Problem:** no bulk edit of generic attributes in QGIS possible, attribute has to be set one by one
# - **Solution:**
#     - either: set description to "teaser_export=true"
#     - or: set class to "1000" -> set building class only on buildings you want to export
#     - use one of these as flags
#
# **Export buildings with 3DCityDB Importer/Exporter**
#
# 1. Export via flag in building description:
#     ```sql
#     SELECT id
#     FROM cityobject
#     WHERE description="teaser_export=true"
#     ```
#     **Problem:** using this query in the 3DCityDB Importer/Exporter only exports building but not buildingparts (subelements of building).
#     trying it in the pgAdmin it outputs the correct cityobject ids for both building and buildingparts.
#
#
# 2. Export via flag in building class:
#     ```sql
#     SELECT building_root_id
#     FROM building
#     WHERE class='1000'
#     ```
#     working fine but not a clean solution
